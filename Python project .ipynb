# %% [markdown]
# # E-Commerce – EDA – Python Project 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set(style="darkgrid")

# %%
Ecommerce_UK_Retailer = pd.read_csv("Ecommerce - UK Retailer.csv")
Ecommerce_UK_Retailer
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# #### Add the new Column Money Spent for calculation ahed.

# %%
Ecommerce_UK_Retailer['Money_Spent'] = Ecommerce_UK_Retailer['Quantity'] * Ecommerce_UK_Retailer['UnitPrice']

# %% [markdown]
# #### Add the Columns Month,Day,Hour

# %%
Ecommerce_UK_Retailer['month'] = list(pd.DatetimeIndex(Ecommerce_UK_Retailer['InvoiceDate']).month)
Ecommerce_UK_Retailer['day'] = list(pd.DatetimeIndex(Ecommerce_UK_Retailer['InvoiceDate']).day)
Ecommerce_UK_Retailer['hour'] = list(pd.DatetimeIndex(Ecommerce_UK_Retailer['InvoiceDate']).hour)

# %%
Ecommerce_UK_Retailer
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Money_Spent  \
# ...

# %%
Ecommerce_UK_Retailer.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# Money_Spent    float64
# month            int64
# day              int64
# hour             int64
# dtype: object

# %% [markdown]
# ## Problem Statements:

# %% [markdown]
# ## 1. Perform Basic EDA

# %% [markdown]
# ### a. Boxplot – All Numeric Variables

# %%
data = Ecommerce_UK_Retailer[['UnitPrice','Quantity']]

red_diamond = dict(markerfacecolor='r', marker='D')

plt.title("Unitprice and Quantity distribution")
plt.boxplot(data.values, labels=["Unit price","Quantity"],flierprops = red_diamond)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x3e35e4f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x3e35e850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x3e35e340>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x3e35ebb0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x3e35ed60>,
# ...
#  'means': []}

# %% [markdown]
# ### b. Histogram – All Numeric Variables

# %%
plt.figure(figsize=(10,4))

plt.title("Unitprice Distribution")

plt.xlabel("Unitprice")
plt.ylabel("Frequency")

plt.hist(Ecommerce_UK_Retailer['UnitPrice'],color='r')
plt.show()

# %%
plt.figure(figsize=(10,4))

plt.title("Quantity Distribution")

plt.xlabel("Quantity")
plt.ylabel("Frequency")

plt.hist(Ecommerce_UK_Retailer['Quantity'],color='y')
plt.show()

# %% [markdown]
# ### c. Distribution Plot – All Numeric Variables

# %%
sns.distplot((Ecommerce_UK_Retailer.head()['UnitPrice']))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='UnitPrice', ylabel='Density'>

# %%
sns.distplot((Ecommerce_UK_Retailer.head()['Quantity']))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Quantity', ylabel='Density'>

# %% [markdown]
# ### d. Aggregation for all numerical Columns

# %%
Ecommerce_UK_Retailer.aggregate({"Quantity" : ['mean','std','median','count','sum','max','min'], 
                   "UnitPrice" : ['mean','std','median','count','sum','max','min'],
                  "CustomerID" : ['mean','std','median','count','sum','max','min'],
                "Money_Spent" : ['mean','std','median','count','sum','max','min']}).round(2)
# Out:
#           Quantity   UnitPrice    CustomerID  Money_Spent
# mean          9.55        4.61  1.528769e+04        17.99
# std         218.08       96.76  1.713600e+03       378.81
# median        3.00        2.08  1.515200e+04         9.75
# count    541909.00   541909.00  4.068290e+05    541909.00
# sum     5176450.00  2498803.97  6.219476e+09   9747747.93
# max       80995.00    38970.00  1.828700e+04    168469.60
# min      -80995.00   -11062.06  1.234600e+04   -168469.60

# %% [markdown]
# ### e. Unique Values across all columns

# %%
Ecommerce_UK_Retailer.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# Money_Spent     6204
# month             12
# day               31
# hour              15
# dtype: int64

# %% [markdown]
# ### f. Duplicate values across all columns

# %%
duplicate = Ecommerce_UK_Retailer[Ecommerce_UK_Retailer.duplicated()]
duplicate
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 517       536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527       536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537       536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539       536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555       536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# ...          ...       ...                                ...       ...
# 541675    581538     22068        BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992             REVOLVER WOODEN RULER          1
# 541699    581538     22694                       WICKER STAR          1
# 541701    581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Money_Spent  \
# ...

# %% [markdown]
# ### g. Correlation – Heatmap - All Numeric Variables

# %%
Ecommerce_UK_Retailer.corr()
# Out:
#              Quantity  UnitPrice  CustomerID  Money_Spent     month       day  \
# Quantity     1.000000  -0.001235   -0.003600     0.886681 -0.001116 -0.000010
# UnitPrice   -0.001235   1.000000   -0.004560    -0.162029 -0.000497 -0.002667
# CustomerID  -0.003600  -0.004560    1.000000    -0.002274  0.030612 -0.001770
# Money_Spent  0.886681  -0.162029   -0.002274     1.000000  0.000141 -0.000259
# month       -0.001116  -0.000497    0.030612     0.000141  1.000000 -0.118878
# day         -0.000010  -0.002667   -0.001770    -0.000259 -0.118878  1.000000
# hour        -0.011268   0.001268    0.064163    -0.009120  0.025649  0.000173
#
#                  hour
# Quantity    -0.011268
# UnitPrice    0.001268
# CustomerID   0.064163
# Money_Spent -0.009120
# month        0.025649
# day          0.000173
# hour         1.000000

# %%
sns.heatmap(Ecommerce_UK_Retailer.corr(), annot = True,linewidths=2,cmap='winter')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### h. Regression Plot - All Numeric Variables

# %%
sns.set_style('whitegrid')
sns.regplot(data=Ecommerce_UK_Retailer, x='Quantity',y='UnitPrice')
plt.title('UnitPrice vs Quantity')
# Out:
# Text(0.5, 1.0, 'UnitPrice vs Quantity')

# %% [markdown]
# ### i. Bar Plot – Every Categorical Variable vs every Numerical Variable

# %%
Ecommerce_UK_Retailer.groupby('Country')['Quantity'].mean()
# Out:
# Country
# Australia               66.444003
# Austria                 12.037406
# Bahrain                 13.684211
# Belgium                 11.189947
# Brazil                  11.125000
# Canada                  18.298013
# Channel Islands         12.505277
# Cyprus                  10.155949
# Czech Republic          19.733333
# Denmark                 21.048843
# EIRE                    17.403245
# European Community       8.147541
# Finland                 15.346763
# France                  12.911067
# Germany                 12.369458
# Greece                  10.657534
# Hong Kong               16.559028
# Iceland                 13.505495
# Israel                  14.656566
# Italy                    9.961395
# Japan                   70.441341
# Lebanon                  8.577778
# Lithuania               18.628571
# Malta                    7.433071
# Netherlands             84.406580
# Norway                  17.722836
# Poland                  10.712610
# ...

# %%
data_country_quantity = Ecommerce_UK_Retailer.groupby('Country')['Quantity'].mean()

x = data_country_quantity.values.tolist()
y = data_country_quantity.index.tolist()

plt.figure(figsize=(20,10))

plt.xlabel("Quantity")
plt.ylabel("Country")

plt.title("Quantity distribution for each country")

plt.barh(y,x,color=['g'])
plt.show()

# %%
Ecommerce_UK_Retailer.groupby('Country')['UnitPrice'].mean()
# Out:
# Country
# Australia                 3.220612
# Austria                   4.243192
# Bahrain                   4.556316
# Belgium                   3.644335
# Brazil                    4.456250
# Canada                    6.030331
# Channel Islands           4.932124
# Cyprus                    6.302363
# Czech Republic            2.938333
# Denmark                   3.256941
# EIRE                      5.911077
# European Community        4.820492
# Finland                   5.448705
# France                    5.028864
# Germany                   3.966930
# Greece                    4.885548
# Hong Kong                42.505208
# Iceland                   2.644011
# Israel                    3.633131
# Italy                     4.831121
# Japan                     2.276145
# Lebanon                   5.387556
# Lithuania                 2.841143
# Malta                     5.244173
# Netherlands               2.738317
# Norway                    6.012026
# ...

# %%
data_country_unitprice = Ecommerce_UK_Retailer.groupby('Country')['UnitPrice'].mean()

x = data_country_unitprice.values.tolist()
y = data_country_unitprice.index.tolist()

plt.figure(figsize=(20,10))

plt.xlabel("Unitprice")
plt.ylabel("Country")

plt.title("Unitprice distribution for each country")

plt.barh(y,x,color=['c'])
plt.show()

# %%
Ecommerce_UK_Retailer.groupby('Country')['CustomerID'].mean()
# Out:
# Country
# Australia               12464.656076
# Austria                 12521.451372
# Bahrain                 12354.529412
# Belgium                 12430.298695
# Brazil                  12769.000000
# Canada                  17321.079470
# Channel Islands         14888.151715
# Cyprus                  12404.951768
# Czech Republic          12781.000000
# Denmark                 12536.591260
# EIRE                    14748.396126
# European Community      15108.000000
# Finland                 12517.012950
# France                  12677.995996
# Germany                 12646.139336
# Greece                  13757.424658
# Hong Kong                        NaN
# Iceland                 12347.000000
# Israel                  12657.868000
# Italy                   12648.397260
# Japan                   12757.798883
# Lebanon                 12764.000000
# Lithuania               15332.000000
# Malta                   16996.031496
# Netherlands             14420.302826
# ...

# %%
data_country_unitprice = Ecommerce_UK_Retailer.groupby('Country')['CustomerID'].mean()

x = data_country_unitprice.values.tolist()
y = data_country_unitprice.index.tolist()

plt.figure(figsize=(20,10))

plt.xlabel("Customerid")
plt.ylabel("Country")

plt.title("Customerid distribution for each country")

plt.barh(y,x,color=['y'])
plt.show()

# %% [markdown]
# ### j. Pair plot - All Numeric Variables

# %%
sns.pairplot(Ecommerce_UK_Retailer,vars=["Quantity","UnitPrice","Money_Spent","Month","Day"])
plt.show()

# %% [markdown]
# ### k. Line chart to show the trend of data - All Numeric/Date Variables

# %%
sns.lineplot(data=Ecommerce_UK_Retailer, x="month", y="Quantity")
# Out:
# <AxesSubplot:xlabel='month', ylabel='Quantity'>

# %%
sns.lineplot(data=Ecommerce_UK_Retailer, x="month", y="UnitPrice")
# Out:
# <AxesSubplot:xlabel='month', ylabel='UnitPrice'>

# %%
sns.lineplot(data=Ecommerce_UK_Retailer, x="month", y="Money_Spent")
# Out:
# <AxesSubplot:xlabel='month', ylabel='Money_Spent'>

# %% [markdown]
# ### l. Plot the skewness - All Numeric Variables

# %%
Ecommerce_UK_Retailer['Skewed Data'] = pd.DataFrame(Ecommerce_UK_Retailer.skew(axis=1,skipna=True))

# %%
sns.histplot(Ecommerce_UK_Retailer['Skewed Data'],bins=10);

# %%
sns.distplot(Ecommerce_UK_Retailer['Skewed Data'].head(), bins=10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Skewed Data', ylabel='Density'>

# %% [markdown]
# ## 2. Check for missing values in all columns and replace them with the appropriate     metric(Mean/Median/Mode)

# %%
Ecommerce_UK_Retailer.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# Money_Spent         0
# month               0
# day                 0
# hour                0
# Skewed Data         0
# dtype: int64

# %%
Ecommerce_UK_Retailer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
#  8   Money_Spent  541909 non-null  float64
#  9   month        541909 non-null  int64
#  10  day          541909 non-null  int64
#  11  hour         541909 non-null  int64
#  12  Skewed Data  541909 non-null  float64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 43.4+ MB

# %%
Ecommerce_UK_Retailer.Description.mode()
# Out:
# 0    WHITE HANGING HEART T-LIGHT HOLDER
# dtype: object

# %%
Ecommerce_UK_Retailer.Description.fillna(Ecommerce_UK_Retailer.Description.mode()[0],inplace = True)

# %%
Ecommerce_UK_Retailer.CustomerID.mean()
# Out:
# 15287.690570239585

# %%
Ecommerce_UK_Retailer['CustomerID'].fillna(Ecommerce_UK_Retailer['CustomerID'].mean(),inplace=True)

# %%
Ecommerce_UK_Retailer.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# Money_Spent    0
# month          0
# day            0
# hour           0
# Skewed Data    0
# dtype: int64

# %% [markdown]
# ## 3. Remove duplicate rows

# %%
Ecommerce_UK_Retailer.duplicated().sum()
# Out:
# 5268

# %%
Ecommerce_UK_Retailer.loc[Ecommerce_UK_Retailer.duplicated()]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 517       536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527       536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537       536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539       536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555       536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# ...          ...       ...                                ...       ...
# 541675    581538     22068        BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992             REVOLVER WOODEN RULER          1
# 541699    581538     22694                       WICKER STAR          1
# 541701    581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Money_Spent  \
# ...

# %%
Ecommerce_UK_Retailer.drop_duplicates(subset=None, keep='first',inplace=True)

# %%
Ecommerce_UK_Retailer.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 4. Remove rows which have negative values in Quantity column

# %%
Ecommerce_UK_Retailer = Ecommerce_UK_Retailer[Ecommerce_UK_Retailer.Quantity > 0]

# %%
Ecommerce_UK_Retailer['Quantity'].describe().round(2)
# Out:
# count    526054.00
# mean         10.73
# std         157.59
# min           1.00
# 25%           1.00
# 50%           4.00
# 75%          11.00
# max       80995.00
# Name: Quantity, dtype: float64

# %% [markdown]
# ## 5. Add the columns - Month, Day and Hour for the invoice

# %%
Ecommerce_UK_Retailer['month'] = list(pd.DatetimeIndex(Ecommerce_UK_Retailer['InvoiceDate']).month)
Ecommerce_UK_Retailer['day'] = list(pd.DatetimeIndex(Ecommerce_UK_Retailer['InvoiceDate']).day)
Ecommerce_UK_Retailer['hour'] = list(pd.DatetimeIndex(Ecommerce_UK_Retailer['InvoiceDate']).hour)

# %%
Ecommerce_UK_Retailer
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Money_Spent  \
# ...

# %% [markdown]
# ## 6. How many orders made by the customers?

# %%
Ecommerce_UK_Retailer.groupby(by=['CustomerID','Country'], as_index=False)['Quantity'].count().head()
# Out:
#    CustomerID         Country  Quantity
# 0     12346.0  United Kingdom         1
# 1     12347.0         Iceland       182
# 2     12348.0         Finland        31
# 3     12349.0           Italy        73
# 4     12350.0          Norway        17

# %%
orders = Ecommerce_UK_Retailer.groupby(by=['CustomerID','Country'], as_index=False)['Quantity'].count()

plt.subplots(figsize=(15,6))
plt.plot(orders.CustomerID, orders.Quantity)
plt.xlabel('Customers ID')
plt.ylabel('Number of Orders')
plt.title('Number of Orders for different Customers')
plt.show()

# %% [markdown]
# ## 7. TOP 5 customers with higher number of orders

# %%
print("Top 5 customers with highest number of orders are : ")
orders.sort_values(by='Quantity', ascending=False).head()
# Out:
# Top 5 customers with highest number of orders are :
#        CustomerID         Country  Quantity
# 2176  15287.69057  United Kingdom    131916
# 4028  17841.00000  United Kingdom      7676
# 1888  14911.00000            EIRE      5672
# 1298  14096.00000  United Kingdom      5111
# 334   12748.00000  United Kingdom      4413

# %% [markdown]
# ## 8. How much money spent by the customers?

# %% [markdown]
# ##### For calculating how much money spent by the customers we have to add the column Money_spent with the help of Quantity and Unitprice.

# %%
Ecommerce_UK_Retailer['Money_Spent'] = Ecommerce_UK_Retailer['Quantity'] * Ecommerce_UK_Retailer['UnitPrice']
# Out:
# <ipython-input-91-aa349934c12f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ecommerce_UK_Retailer['Money_Spent'] = Ecommerce_UK_Retailer['Quantity'] * Ecommerce_UK_Retailer['UnitPrice']

# %%
money_spent = Ecommerce_UK_Retailer.groupby(by=['CustomerID','Country'], as_index=False)['Money_Spent'].sum()
money_spent.head()
# Out:
#    CustomerID         Country  Money_Spent
# 0     12346.0  United Kingdom     77183.60
# 1     12347.0         Iceland      4310.00
# 2     12348.0         Finland      1797.24
# 3     12349.0           Italy      1757.55
# 4     12350.0          Norway       334.40

# %%
money_spent =  Ecommerce_UK_Retailer.groupby(by=['CustomerID','Country'], as_index=False)['Money_Spent'].sum()

plt.subplots(figsize=(15,6))
plt.plot(money_spent.CustomerID, money_spent.Money_Spent)
plt.xlabel('Customers ID')
plt.ylabel('Money spent (Dollar)')
plt.title('Money Spent for different Customers')
plt.show()

# %% [markdown]
# ## 9. TOP 5 customers with highest money spent

# %%
print("TOP 5 customers with highest money spent are : ")
money_spent.sort_values(by='Money_Spent',ascending=False).head().round(2)
# Out:
# TOP 5 customers with highest money spent are :
#       CustomerID         Country  Money_Spent
# 2176    15287.69  United Kingdom   1694595.33
# 1698    14646.00     Netherlands    280206.02
# 4219    18102.00  United Kingdom    259657.30
# 3746    17450.00  United Kingdom    194390.79
# 3026    16446.00  United Kingdom    168472.50

# %% [markdown]
# ## 10. How many orders per month?

# %%
order = Ecommerce_UK_Retailer.groupby(by=['month'])['Quantity'].count().sort_index()
order.plot(kind = 'bar',figsize=(15,6))
plt.xlabel('Month')
plt.ylabel('Number of Orders')
plt.title('Number of orders for different Months')
plt.show()

# %% [markdown]
# ## 11. How many orders per day?

# %%
order = Ecommerce_UK_Retailer.groupby(by=['day'])['Quantity'].count().sort_index()
order.plot(kind = 'bar',figsize=(15,6))
plt.xlabel('Day')
plt.ylabel('Number of Orders')
plt.title('Number of orders for Days')
plt.show()

# %% [markdown]
# ## 12. How many orders per hour?

# %%
order = Ecommerce_UK_Retailer.groupby(by=['hour'])['Quantity'].count().sort_index()
order.plot(kind = 'bar',figsize=(15,6))
plt.xlabel('Hour')
plt.ylabel('Number of Orders')
plt.title('Number of orders for hours')
plt.show()

# %% [markdown]
# ## 13. How many orders for each country?

# %%
group_country_orders = Ecommerce_UK_Retailer.groupby('Country')['InvoiceNo'].count().sort_values()

plt.subplots(figsize=(15,8))
group_country_orders.plot(kind = 'barh')
plt.xlabel('Number of Orders')
plt.ylabel('Country')
plt.title('Number of Orders for different Countries with UK')
plt.show()

# %%
group_country_orders = Ecommerce_UK_Retailer.groupby('Country')['InvoiceNo'].count().sort_values()

del group_country_orders['United Kingdom']

plt.subplots(figsize=(15,8))
group_country_orders.plot(kind = 'barh')
plt.xlabel('Number of Orders')
plt.ylabel('Country')
plt.title('Number of Orders for different Countries without UK')
plt.show()

# %% [markdown]
# ## 14. Orders trend across months

# %%
fig = plt.figure(figsize=(15, 7))
x1 = fig.add_subplot(111)

x1.set_xlabel('Month',fontsize=15)
x1.set_ylabel('Total Amount Spent',fontsize=15)
x1.set_title('Total Amount Spent for Months',fontsize=15)

x1.bar(Ecommerce_UK_Retailer.groupby(by=['month'])['Money_Spent'].sum().index.tolist()[1:],
        Ecommerce_UK_Retailer.groupby(by=['month'])['Money_Spent'].sum()[1:],
        alpha=0.85,
        label='Amount Spent by Month')

x2 = x1.twinx()

x2.set_ylabel('Percentage Change of Total Amount Spent (%)',fontsize=15)

x2.plot(Ecommerce_UK_Retailer.groupby(by=['month'])['Money_Spent'].sum().index.tolist()[1:], 
         Ecommerce_UK_Retailer.groupby(by=['month'])['Money_Spent'].sum()[1:].pct_change().fillna(0)*100,
         label='Percentage change of total amount spent (%)',
         color='red')

x1.legend(loc='upper left')
x2.legend(loc='upper right')

fig.tight_layout()
plt.show()

# %% [markdown]
# ## 15. How much money spent by each country?

# %%
group_country_money_spent = Ecommerce_UK_Retailer.groupby('Country')['Money_Spent'].sum().sort_values()

plt.subplots(figsize=(15,8))
group_country_money_spent.plot(kind = 'barh')
plt.xlabel('Money Spent (Dollar)')
plt.ylabel('Country')
plt.title('Money Spent by different Countries with UK')
plt.show()

# %%
group_country_money_spent = Ecommerce_UK_Retailer.groupby('Country')['Money_Spent'].sum().sort_values()

del group_country_money_spent['United Kingdom']

plt.subplots(figsize=(15,8))
group_country_money_spent.plot(kind = 'barh')
plt.xlabel('Money Spent (Dollar)')
plt.ylabel('Country')
plt.title('Money Spent by different Countries without UK')
plt.show()
